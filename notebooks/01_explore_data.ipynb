# %%
import pandas as pd

# %%
df_original = pd.read_csv("../data/01_raw/Different_stores_dataset.csv")

# %%
df_original.shape
# Out:
# (99457, 13)

# %%
df_original.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   invoice_no              99457 non-null  str
#  1   invoice_date            99457 non-null  str
#  2   customer_id             99457 non-null  str
#  3   gender                  99457 non-null  str
#  4   age                     99457 non-null  int64
#  5   category                99457 non-null  str
#  6   quantity                99457 non-null  int64
#  7   selling_price_per_unit  99457 non-null  float64
#  8   cost_price_per_unit     99457 non-null  float64
#  9   payment_method          99457 non-null  str
#  10  region                  99457 non-null  str
#  11  state                   99457 non-null  str
#  12  shopping_mall           99457 non-null  str
# dtypes: float64(2), int64(2), str(9)
# memory usage: 9.9 MB

# %%
df_original["invoice_no"].nunique()

# %%
len(df_original)
